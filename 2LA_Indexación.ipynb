# %%
#INSTALAR LIBRERIAS
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install openpyxl

# %%
#Importamos librerías requeridas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Convertimos el dataset en dataframe
df= pd.read_csv("listings.csv") # CAMBIAR EL NOMBRE 
df
# Out:
#                         id                                       listing_url  \
# 0                     2708                 https://www.airbnb.com/rooms/2708
# 1                     2732                 https://www.airbnb.com/rooms/2732
# 2                     2864                 https://www.airbnb.com/rooms/2864
# 3                     6033                 https://www.airbnb.com/rooms/6033
# 4                     6931                 https://www.airbnb.com/rooms/6931
# ...                    ...                                               ...
# 45416  1443394805958459680  https://www.airbnb.com/rooms/1443394805958459680
# 45417  1443394831515560629  https://www.airbnb.com/rooms/1443394831515560629
# 45418  1443394885201303898  https://www.airbnb.com/rooms/1443394885201303898
# 45419  1443449500529637549  https://www.airbnb.com/rooms/1443449500529637549
# 45420  1443465434447227262  https://www.airbnb.com/rooms/1443465434447227262
#
# ...

# %%
#Verificamos información del DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45421 entries, 0 to 45420
# Data columns (total 79 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            45421 non-null  int64
#  1   listing_url                                   45421 non-null  object
#  2   scrape_id                                     45421 non-null  int64
#  3   last_scraped                                  45421 non-null  object
#  4   source                                        45421 non-null  object
#  5   name                                          45420 non-null  object
#  6   description                                   44399 non-null  object
#  7   neighborhood_overview                         20350 non-null  object
#  8   picture_url                                   45421 non-null  object
# ...

# %% [markdown]
# ***Un array 2D con las columnas***

# %%
columnas1 = df[['host_name', 'host_since','host_neighbourhood', 'property_type', 'room_type','price']] #pueden ser consecutivas o no consecutivas
columnas1
# Out:
#           host_name  host_since            host_neighbourhood  \
# 0             Chas.  2008-09-16                     Hollywood
# 1      Louise-Diane  2008-09-17                  Santa Monica
# 2         Bernadine  2008-09-25                    Bellflower
# 3             Sarah  2009-03-28  Woodland Hills/Warner Center
# 4             Chas.  2008-09-16                     Hollywood
# ...             ...         ...                           ...
# 45416           Jan  2025-01-20            Webster Park North
# 45417           Jan  2025-01-20            Webster Park North
# 45418           Jan  2025-01-20            Webster Park North
# 45419        Rachel  2017-02-06                Central Malibu
# 45420       Theresa  2015-03-26              Hawaiian Gardens
#
#                      property_type        room_type    price
# 0      Private room in rental unit     Private room  $110.00
# 1      Private room in rental unit     Private room  $118.00
# ...

# %%
#Convertir array a CSV
columnas1.to_csv("Entregable(a).csv")

# %% [markdown]
# *** (b) Un array 2D con las filas. ***

# %%
df2= df.iloc[ [1] + [50] + list(range(100, 201)) + [499] + [500] + [605] + [1500] + [8000] + [15000] , : ] 
df2
# Out:
#              id                            listing_url       scrape_id  \
# 1          2732      https://www.airbnb.com/rooms/2732  20250617032927
# 50       131557    https://www.airbnb.com/rooms/131557  20250617032927
# 100       20585     https://www.airbnb.com/rooms/20585  20250617032927
# 101      183319    https://www.airbnb.com/rooms/183319  20250617032927
# 102      188081    https://www.airbnb.com/rooms/188081  20250617032927
# ...         ...                                    ...             ...
# 500     1257025   https://www.airbnb.com/rooms/1257025  20250617032927
# 605     1042282   https://www.airbnb.com/rooms/1042282  20250617032927
# 1500    4121396   https://www.airbnb.com/rooms/4121396  20250617032927
# 8000   24806579  https://www.airbnb.com/rooms/24806579  20250617032927
# 15000  47962676  https://www.airbnb.com/rooms/47962676  20250617032927
#
#       last_scraped           source  \
# 1       2025-06-17      city scrape
# 50      2025-06-18      city scrape
# ...

# %%
#Convertir array a CSV
df2.to_csv("Entregable(b).csv")

# %% [markdown]
# ***Un array 2D con las filas: 125, 252, 300-550, 700, 1000, 1250-la última fila y con las columnas: host_id, host_location, host_acceptance_rate, bathrooms, amenities, review_scores_value.***

# %%
df4= df.iloc[ [1] + [50] + list(range(100, 201)) + [499] + [500] + [605] + [1500] + [8000] + [15000] , [9]+ [13]+ [17]+ [35]+ [39] +[71] ] 
df4
# Out:
#         host_id     host_location host_acceptance_rate  bathrooms  \
# 1          3041  Santa Monica, CA                  50%        1.0
# 50        78804   Los Angeles, CA                  43%        1.0
# 100       77857   Los Angeles, CA                  17%        1.0
# 101      867995   Los Angeles, CA                  NaN        1.0
# 102      905689   Los Angeles, CA                  NaN        NaN
# ...         ...               ...                  ...        ...
# 500     6471245  Santa Monica, CA                 100%        1.0
# 605     1180786   Los Angeles, CA                  90%        1.0
# 1500   17942313   Los Angeles, CA                  NaN        NaN
# 8000   27772889   Los Angeles, CA                  NaN        NaN
# 15000   4240522   Los Angeles, CA                  98%        2.0
#
#                                                amenities  review_scores_value
# 1      ["Host greets you", "Free street parking", "Re...                 4.22
# ...

# %%
# Un array 2D con las filas: 125, 252, 300-550, 700, 1000, 1250-la última fila y con las columnas: host_id, host_location, host_acceptance_rate, bathrooms, amenities, review_scores_value
df5 = df.loc[[125, 252] + list(range(300, 551)) + [700, 1000, 1250, df.shape[0] - 1], ['host_id', 'host_location', 'host_acceptance_rate', 'bathrooms', 'amenities', 'review_scores_value']]
df5
# Out:
#         host_id      host_location host_acceptance_rate  bathrooms  \
# 125       76111    Los Angeles, CA                  NaN        3.0
# 252     3393312    Los Angeles, CA                 100%        1.0
# 300     2122283    Los Angeles, CA                  NaN        1.0
# 301     1678136  São Paulo, Brazil                   0%        4.0
# 302      309512    Los Angeles, CA                  95%        1.0
# ...         ...                ...                  ...        ...
# 550     6483621    Los Angeles, CA                  80%        1.0
# 700      975343       Monrovia, CA                  67%        3.0
# 1000   13789616  Monterey Park, CA                 100%        2.5
# 1250   13735500    Los Angeles, CA                  NaN        NaN
# 45420  30071757                NaN                  NaN        2.0
#
#                                                amenities  review_scores_value
# 125    ["Stove", "Extra pillows and blankets", "Host ...                 4.64
# ...

# %%
#Convertir array a CSV
df5.to_csv("Entregable(c).csv")

# %%
columnas_50 = df.columns[:50]

# Crear el array 2D solo con esas columnas
array_2d = df[columnas_50]

# Mostrar el resultado
print(array_2d)
# Out:
#                         id                                       listing_url  \
# 0                     2708                 https://www.airbnb.com/rooms/2708
# 1                     2732                 https://www.airbnb.com/rooms/2732
# 2                     2864                 https://www.airbnb.com/rooms/2864
# 3                     6033                 https://www.airbnb.com/rooms/6033
# 4                     6931                 https://www.airbnb.com/rooms/6931
# ...                    ...                                               ...
# 45416  1443394805958459680  https://www.airbnb.com/rooms/1443394805958459680
# 45417  1443394831515560629  https://www.airbnb.com/rooms/1443394831515560629
# 45418  1443394885201303898  https://www.airbnb.com/rooms/1443394885201303898
# 45419  1443449500529637549  https://www.airbnb.com/rooms/1443449500529637549
# 45420  1443465434447227262  https://www.airbnb.com/rooms/1443465434447227262
#
# ...

# %% [markdown]
# *** Generar un Archivo.csv por cada dataframe obtenido en el punto 3. respaldarlo en GitHub. ***

# %%
#Filas combinadas y Todas las columnas
df= df.iloc[ :,list(range(2, 8)) + list(range(9, 19)) + list(range(21, 24)) + [26] + [28] + list(range(30, 34)) + [35] + [38] + list(range(40, 43)) + list(range(50, 57)) + list(range(61, 66)) + list(range(67, 73)) + [74] + [78] ]
df.info()

print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45421 entries, 0 to 45420
# Data columns (total 50 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   scrape_id                       45421 non-null  int64
#  1   last_scraped                    45421 non-null  object
#  2   source                          45421 non-null  object
#  3   name                            45420 non-null  object
#  4   description                     44399 non-null  object
#  5   neighborhood_overview           20350 non-null  object
#  6   host_id                         45421 non-null  int64
#  7   host_url                        45421 non-null  object
#  8   host_name                       45416 non-null  object
#  9   host_since                      45414 non-null  object
#  10  host_location                   34640 non-null  object
#  11  host_about                      24875 non-null  object
# ...

# %%
#Convertir array a CSV
df.to_csv("Entregable(d).csv")

# %%
#Convertir array a CSV
df.to_csv("Entregable1.csv")
